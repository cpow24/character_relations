# %% [markdown]
# **Preliminaries:** Some local paths have been changed in order to be able to run in colab, below is a list of files and locations where a change has been made. Replace the local path with whatever the equivalent is on your drive.
#
# - ../src/mention_model/main.py (line 7)
# - ../src/data_processing/independent_litbank.py (line 12)
# - ../src/data_processing/overlap_litbank.py (line 12)
# - ../src/auto_memory_model/main.py (line 9)

# %% [markdown]
# **STEP 1:** Mount Google Drive and import libraries

# %%
from google.colab import drive
drive.mount('/content/drive')

# !pip install transformers
# !pip install -r requirements.txt
# !git clone https://github.com/conll/reference-coreference-scorers
# !git clone https://github.com/dbamman/lrec2020-coref
# Out:
# Mounted at /content/drive
# ...
#      |████████████████████████████████| 4.0 MB 5.1 MB/s
# ...
#      |████████████████████████████████| 596 kB 61.8 MB/s
# ...
#      |████████████████████████████████| 895 kB 59.2 MB/s
# ...
#      |████████████████████████████████| 6.5 MB 51.4 MB/s
# ...
#      |████████████████████████████████| 77 kB 8.8 MB/s
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'
# Cloning into 'reference-coreference-scorers'...
# remote: Enumerating objects: 591, done.
# remote: Total 591 (delta 0), reused 0 (delta 0), pack-reused 591
# Receiving objects: 100% (591/591), 168.31 KiB | 4.67 MiB/s, done.
# Resolving deltas: 100% (318/318), done.
# Cloning into 'lrec2020-coref'...
# remote: Enumerating objects: 356, done.
# remote: Counting objects: 100% (356/356), done.
# ...

# %%
# %cd /content/drive/MyDrive/NLP_CW/LH/long-doc-coref_edit
# Out:
# /content/drive/.shortcut-targets-by-id/1GVWP5LpWabZMZpv1TUP_zN78uLXiJF-b/NLP_CW/LH/long-doc-coref_edit

# %%
#%cd lrec2020-coref/
# Out:
# /content/drive/.shortcut-targets-by-id/1GVWP5LpWabZMZpv1TUP_zN78uLXiJF-b/NLP_CW/LH/long-doc-coref_edit/lrec2020-coref

# %% [markdown]
# **STEP 2:** Getting .conll files and splitting them for 10-fold cross-validation

# %%
#!python scripts/create_crossval.py ../data/litbank_tenfold_splits ../data/new_conll  ../data/litbank_people_only_splits
# Out:
# python3: can't open file 'scripts/create_crossval.py': [Errno 2] No such file or directory

# %%
#!python data_processing/overlap_litbank.py ../data/litbank_people_only_splits ../data/litbank_people_only/overlap
# Out:
# Minimizing ../data/litbank_people_only_splits/0/dev.conll
# Wrote 10 documents to ../data/litbank_people_only/overlap/0/dev.512.jsonlines
# Minimizing ../data/litbank_people_only_splits/0/train.conll
# Wrote 80 documents to ../data/litbank_people_only/overlap/0/train.512.jsonlines
# Minimizing ../data/litbank_people_only_splits/0/test.conll
# Wrote 10 documents to ../data/litbank_people_only/overlap/0/test.512.jsonlines
# max_sent_len = 384
# Minimizing ../data/litbank_people_only_splits/1/dev.conll
# Wrote 10 documents to ../data/litbank_people_only/overlap/1/dev.512.jsonlines
# Minimizing ../data/litbank_people_only_splits/1/train.conll
# Wrote 80 documents to ../data/litbank_people_only/overlap/1/train.512.jsonlines
# Minimizing ../data/litbank_people_only_splits/1/test.conll
# Wrote 10 documents to ../data/litbank_people_only/overlap/1/test.512.jsonlines
# max_sent_len = 384
# Minimizing ../data/litbank_people_only_splits/2/dev.conll
# ...

# %% [markdown]
# **STEP 3:** Training Mention Model on new_conll Dataset

# %%
# %cd src
# Out:
# /content/drive/.shortcut-targets-by-id/1GVWP5LpWabZMZpv1TUP_zN78uLXiJF-b/NLP_CW/LH/long-doc-coref_edit/src

# %%
#people-mentions only mention model
# !python mention_model/main.py -dataset litbank_person_only -cross_val_split 0 -max_span_width 20 -top_span_ratio 0.3 -max_epochs 15 -ment_emb attn
# Out:
# ment_litbank_person_only_width_20_mlp_3000_model_large_emb_attn_type_spanbert_enc_overlap_segment_512
# data dir ../data/litbank_person_only/overlap/0
# ../data/litbank_person_only/overlap/0
# ../data/litbank_person_only/overlap/0 ../data/litbank_person_only/overlap/0/train.512.jsonlines
# ../data/litbank_person_only/overlap/0
# ../data/litbank_person_only/overlap/0 ../data/litbank_person_only/overlap/0/dev.512.jsonlines
# ../data/litbank_person_only/overlap/0
# ../data/litbank_person_only/overlap/0 ../data/litbank_person_only/overlap/0/test.512.jsonlines
# mention_attn.weight torch.Size([1, 1024])
# mention_attn.bias torch.Size([1])
# span_width_embeddings.weight torch.Size([20, 20])
# span_width_prior_embeddings.weight torch.Size([20, 20])
# mention_mlp.fc_layers.0.weight torch.Size([3000, 3092])
# mention_mlp.fc_layers.0.bias torch.Size([3000])
# mention_mlp.fc_layers.3.weight torch.Size([1, 3000])
# mention_mlp.fc_layers.3.bias torch.Size([1])
# ...

# %%
# !python mention_model/main.py -dataset litbank_person_only -cross_val_split 0 -max_span_width 20 -top_span_ratio 0.25 -max_epochs 15 -ment_emb attn
# Out:
# ment_litbank_person_only_width_20_mlp_3000_model_large_emb_attn_type_spanbert_enc_overlap_segment_512
# data dir ../data/litbank_person_only/overlap/0
# ../data/litbank_person_only/overlap/0
# ../data/litbank_person_only/overlap/0 ../data/litbank_person_only/overlap/0/train.512.jsonlines
# ../data/litbank_person_only/overlap/0
# ../data/litbank_person_only/overlap/0 ../data/litbank_person_only/overlap/0/dev.512.jsonlines
# ../data/litbank_person_only/overlap/0
# ../data/litbank_person_only/overlap/0 ../data/litbank_person_only/overlap/0/test.512.jsonlines
# Downloading: 100% 521/521 [00:00<00:00, 908kB/s]
# Downloading: 100% 1.24G/1.24G [00:31<00:00, 42.3MB/s]
# Downloading: 100% 208k/208k [00:00<00:00, 3.63MB/s]
# Downloading: 100% 29.0/29.0 [00:00<00:00, 54.4kB/s]
# Downloading: 100% 570/570 [00:00<00:00, 1.09MB/s]
# ...

# %%
# !python mention_model/main.py -dataset litbank_person_only -cross_val_split 0 -max_span_width 20 -top_span_ratio 0.25 -max_epochs 15 -ment_emb attn
# Out:
# ment_litbank_person_only_width_21_mlp_3000_model_large_emb_attn_type_spanbert_enc_overlap_segment_512
# data dir ../data/litbank_person_only/overlap/0
# ../data/litbank_person_only/overlap/0
# ../data/litbank_person_only/overlap/0 ../data/litbank_person_only/overlap/0/train.512.jsonlines
# ../data/litbank_person_only/overlap/0
# ../data/litbank_person_only/overlap/0 ../data/litbank_person_only/overlap/0/dev.512.jsonlines
# ../data/litbank_person_only/overlap/0
# ../data/litbank_person_only/overlap/0 ../data/litbank_person_only/overlap/0/test.512.jsonlines
# mention_attn.weight torch.Size([1, 1024])
# mention_attn.bias torch.Size([1])
# span_width_embeddings.weight torch.Size([21, 20])
# span_width_prior_embeddings.weight torch.Size([21, 20])
# mention_mlp.fc_layers.0.weight torch.Size([3000, 3092])
# mention_mlp.fc_layers.0.bias torch.Size([3000])
# mention_mlp.fc_layers.3.weight torch.Size([1, 3000])
# mention_mlp.fc_layers.3.bias torch.Size([1])
# ...

# %%
#paper mention model evaluated on original dataset
# !python mention_model/main.py -cross_val_split 0 -max_span_width 20 -top_span_ratio 0.3 -max_epochs 15 -ment_emb attn -eval True
# Out:
# ment_litbank_width_20_mlp_3000_model_large_emb_attn_type_spanbert_enc_overlap_segment_512_split_0
# data dir ../data/litbank/overlap/0
# ../data/litbank/overlap/0
# ../data/litbank/overlap/0 ../data/litbank/overlap/0/train.512.jsonlines
# ../data/litbank/overlap/0
# ../data/litbank/overlap/0 ../data/litbank/overlap/0/dev.512.jsonlines
# ../data/litbank/overlap/0
# ../data/litbank/overlap/0 ../data/litbank/overlap/0/test.512.jsonlines
# 2022-04-02 11:03:55,306 - Loading previous model: ../models/paper_model/best_models/model.pth
# mention_attn.weight torch.Size([1, 1024])
# mention_attn.bias torch.Size([1])
# span_width_embeddings.weight torch.Size([20, 20])
# span_width_prior_embeddings.weight torch.Size([20, 20])
# mention_mlp.fc_layers.0.weight torch.Size([3000, 3092])
# mention_mlp.fc_layers.0.bias torch.Size([3000])
# mention_mlp.fc_layers.3.weight torch.Size([1, 3000])
# mention_mlp.fc_layers.3.bias torch.Size([1])
# span_width_mlp.fc_layers.0.weight torch.Size([3000, 20])
# ...

# %%
#paper mention model on person_only dataset
# !python mention_model/main.py -dataset litbank_person_only -cross_val_split 0 -max_span_width 20 -top_span_ratio 0.3 -max_epochs 15 -ment_emb attn -eval True
# Out:
# ment_litbank_person_only_width_20_mlp_3000_model_large_emb_attn_type_spanbert_enc_overlap_segment_512
# data dir ../data/litbank_person_only/overlap/0
# ../data/litbank_person_only/overlap/0
# ../data/litbank_person_only/overlap/0 ../data/litbank_person_only/overlap/0/train.512.jsonlines
# ../data/litbank_person_only/overlap/0
# ../data/litbank_person_only/overlap/0 ../data/litbank_person_only/overlap/0/dev.512.jsonlines
# ../data/litbank_person_only/overlap/0
# ../data/litbank_person_only/overlap/0 ../data/litbank_person_only/overlap/0/test.512.jsonlines
# 2022-04-02 11:07:02,321 - Loading previous model: ../models/paper_model/best_models/model.pth
# mention_attn.weight torch.Size([1, 1024])
# mention_attn.bias torch.Size([1])
# span_width_embeddings.weight torch.Size([20, 20])
# span_width_prior_embeddings.weight torch.Size([20, 20])
# mention_mlp.fc_layers.0.weight torch.Size([3000, 3092])
# mention_mlp.fc_layers.0.bias torch.Size([3000])
# ...

# %% [markdown]
# **STEP 4:** Training of Coreference Model (on original dataset)

# %%
#EVALUATE paper coref model on original dataset
# !python auto_memory_model/main.py -dataset litbank -mem_type learned -num_cells 20 -top_span_ratio 0.3 -max_span_width 20 -max_epochs 3 -dropout_rate 0.3 -sample_invalid 0.25 -new_ent_wt 2.0 -cross_val_split 3 -max_training_segments 5 -seed 0 -eval True

# %%
# !python auto_memory_model/main.py -dataset litbank -mem_type learned -num_cells 20 -top_span_ratio 0.3 -max_span_width 20 -max_epochs 3 -dropout_rate 0.3 -sample_invalid 0.25 -new_ent_wt 2.0 -cross_val_split 3 -max_training_segments 5 -seed 0 -eval True
# Out:
# ../models/paper_model
# ../data/litbank/overlap/3
# ../models/paper_mention_model/best_models/model.pth
# 2022-04-05 20:12:50,262 - dataset: litbank
# 2022-04-05 20:12:50,263 - model_size: large
# 2022-04-05 20:12:50,263 - doc_enc: overlap
# 2022-04-05 20:12:50,263 - max_segment_len: 512
# 2022-04-05 20:12:50,263 - max_span_width: 20
# 2022-04-05 20:12:50,263 - ment_emb: attn
# 2022-04-05 20:12:50,263 - top_span_ratio: 0.3
# 2022-04-05 20:12:50,263 - mem_type: learned
# 2022-04-05 20:12:50,263 - num_cells: 20
# 2022-04-05 20:12:50,263 - mlp_size: 3000
# 2022-04-05 20:12:50,264 - mlp_depth: 1
# 2022-04-05 20:12:50,264 - entity_rep: wt_avg
# 2022-04-05 20:12:50,264 - emb_size: 20
# 2022-04-05 20:12:50,264 - cross_val_split: 3
# 2022-04-05 20:12:50,264 - new_ent_wt: 2.0
# 2022-04-05 20:12:50,264 - num_train_docs: None
# 2022-04-05 20:12:50,264 - max_training_segments: 5
# 2022-04-05 20:12:50,264 - sample_invalid: 0.25
# 2022-04-05 20:12:50,264 - dropout_rate: 0.3
# ...

# %%
# !python auto_memory_model/main.py -dataset litbank_person_only -mem_type learned -num_cells 20 -top_span_ratio 0.3 -max_span_width 20 -max_epochs 3 -dropout_rate 0.3 -sample_invalid 0.25 -new_ent_wt 2.0 -cross_val_split 3 -max_training_segments 5 -seed 0 -eval True -mention_model ment_litbank_person_only_width_20_mlp_3000_model_large_emb_attn_type_spanbert_enc_overlap_segment_512 -eval_model coref_04657d4d68300a4a7cb80b08a21103ea
# Out:
# ../models/coref_04657d4d68300a4a7cb80b08a21103ea
# ../data/litbank_person_only/overlap/3
# ../models/ment_litbank_person_only_width_20_mlp_3000_model_large_emb_attn_type_spanbert_enc_overlap_segment_512/best_models/model.pth
# 2022-04-06 15:10:30,929 - dataset: litbank_person_only
# 2022-04-06 15:10:30,929 - model_size: large
# 2022-04-06 15:10:30,929 - doc_enc: overlap
# 2022-04-06 15:10:30,929 - max_segment_len: 512
# 2022-04-06 15:10:30,929 - max_span_width: 20
# 2022-04-06 15:10:30,929 - ment_emb: attn
# 2022-04-06 15:10:30,930 - top_span_ratio: 0.3
# 2022-04-06 15:10:30,930 - mem_type: learned
# 2022-04-06 15:10:30,930 - num_cells: 20
# 2022-04-06 15:10:30,930 - mlp_size: 3000
# 2022-04-06 15:10:30,930 - mlp_depth: 1
# 2022-04-06 15:10:30,930 - entity_rep: wt_avg
# 2022-04-06 15:10:30,930 - emb_size: 20
# 2022-04-06 15:10:30,930 - cross_val_split: 3
# 2022-04-06 15:10:30,930 - new_ent_wt: 2.0
# 2022-04-06 15:10:30,930 - num_train_docs: None
# ...

# %%
# EVALUATE paper coref model on person_only dataset
# !python auto_memory_model/main.py -dataset litbank_person_only -mem_type learned -num_cells 20 -top_span_ratio 0.3 -max_span_width 20 -max_epochs 3 -dropout_rate 0.3 -sample_invalid 0.25 -new_ent_wt 2.0 -cross_val_split 3 -max_training_segments 5 -seed 0 -eval True -mention_model ment_litbank_person_only_width_20_mlp_3000_model_large_emb_attn_type_spanbert_enc_overlap_segment_512 -eval_model current_person_only_best
# Out:
# ../models/current_person_only_best
# ../data/litbank_person_only/overlap/3
# ../models/ment_litbank_person_only_width_20_mlp_3000_model_large_emb_attn_type_spanbert_enc_overlap_segment_512/best_models/model.pth
# 2022-04-06 15:11:56,526 - dataset: litbank_person_only
# 2022-04-06 15:11:56,527 - model_size: large
# 2022-04-06 15:11:56,527 - doc_enc: overlap
# 2022-04-06 15:11:56,527 - max_segment_len: 512
# 2022-04-06 15:11:56,527 - max_span_width: 20
# 2022-04-06 15:11:56,527 - ment_emb: attn
# 2022-04-06 15:11:56,527 - top_span_ratio: 0.3
# 2022-04-06 15:11:56,527 - mem_type: learned
# 2022-04-06 15:11:56,527 - num_cells: 20
# 2022-04-06 15:11:56,527 - mlp_size: 3000
# 2022-04-06 15:11:56,527 - mlp_depth: 1
# 2022-04-06 15:11:56,527 - entity_rep: wt_avg
# 2022-04-06 15:11:56,527 - emb_size: 20
# 2022-04-06 15:11:56,527 - cross_val_split: 3
# 2022-04-06 15:11:56,528 - new_ent_wt: 2.0
# 2022-04-06 15:11:56,528 - num_train_docs: None
# ...

# %%
#best precision model
# !python auto_memory_model/main.py -dataset litbank_person_only -mem_type learned -num_cells 20 -top_span_ratio 0.3 -max_span_width 20 -max_epochs 25 -dropout_rate 0.35 -sample_invalid 0.25 -new_ent_wt 2 -cross_val_split 3 -max_training_segments 5 -seed 0 -mention_model ment_litbank_person_only_width_20_mlp_3000_model_large_emb_attn_type_spanbert_enc_overlap_segment_512
# Out:
# ../models/coref_2c62b63a1d2107140cc9d8efdfc5d952
# ../data/litbank_person_only/overlap/3
# ../models/ment_litbank_person_only_width_20_mlp_3000_model_large_emb_attn_type_spanbert_enc_overlap_segment_512/best_models/model.pth
# 2022-04-06 15:24:44,207 - dataset: litbank_person_only
# 2022-04-06 15:24:44,207 - model_size: large
# 2022-04-06 15:24:44,207 - doc_enc: overlap
# 2022-04-06 15:24:44,207 - max_segment_len: 512
# 2022-04-06 15:24:44,207 - max_span_width: 20
# 2022-04-06 15:24:44,207 - ment_emb: attn
# 2022-04-06 15:24:44,207 - top_span_ratio: 0.3
# 2022-04-06 15:24:44,207 - mem_type: learned
# 2022-04-06 15:24:44,207 - num_cells: 20
# 2022-04-06 15:24:44,207 - mlp_size: 3000
# 2022-04-06 15:24:44,208 - mlp_depth: 1
# 2022-04-06 15:24:44,208 - entity_rep: wt_avg
# 2022-04-06 15:24:44,208 - emb_size: 20
# 2022-04-06 15:24:44,208 - cross_val_split: 3
# 2022-04-06 15:24:44,208 - new_ent_wt: 2.0
# 2022-04-06 15:24:44,208 - num_train_docs: None
# ...

# %%
# !python auto_memory_model/main.py -dataset litbank_person_only -mem_type learned -num_cells 20 -top_span_ratio 0.3 -max_span_width 20 -max_epochs 3 -dropout_rate 0.3 -sample_invalid 0.25 -new_ent_wt 2.0 -cross_val_split 3 -max_training_segments 5 -seed 0 -eval True -mention_model ment_litbank_person_only_width_20_mlp_3000_model_large_emb_attn_type_spanbert_enc_overlap_segment_512 -eval_model /content/drive/MyDrive/NLP_CW/LH/long-doc-coref_edit/models/current_person_only_best

# %%
#train coref model person_only_dataset
# !python auto_memory_model/main.py -dataset litbank_person_only -mem_type learned -num_cells 20 -top_span_ratio 0.3 -max_span_width 20 -max_epochs 25 -dropout_rate 0.3 -sample_invalid 0.25 -new_ent_wt 2.0 -cross_val_split 3 -max_training_segments 5 -seed 0 -mention_model ment_litbank_person_only_width_20_mlp_3000_model_large_emb_attn_type_spanbert_enc_overlap_segment_512
# Out:
# ../models/../james/models/coref_04657d4d68300a4a7cb80b08a21103ea
# ../data/litbank_person_only/overlap/3
# ../models/ment_litbank_person_only_width_20_mlp_3000_model_large_emb_attn_type_spanbert_enc_overlap_segment_512/best_models/model.pth
# 2022-04-06 11:11:33,227 - dataset: litbank_person_only
# 2022-04-06 11:11:33,227 - model_size: large
# 2022-04-06 11:11:33,227 - doc_enc: overlap
# 2022-04-06 11:11:33,227 - max_segment_len: 512
# 2022-04-06 11:11:33,227 - max_span_width: 20
# 2022-04-06 11:11:33,227 - ment_emb: attn
# 2022-04-06 11:11:33,227 - top_span_ratio: 0.3
# 2022-04-06 11:11:33,227 - mem_type: learned
# 2022-04-06 11:11:33,228 - num_cells: 20
# 2022-04-06 11:11:33,228 - mlp_size: 3000
# 2022-04-06 11:11:33,228 - mlp_depth: 1
# 2022-04-06 11:11:33,228 - entity_rep: wt_avg
# 2022-04-06 11:11:33,228 - emb_size: 20
# 2022-04-06 11:11:33,228 - cross_val_split: 3
# 2022-04-06 11:11:33,228 - new_ent_wt: 2.0
# 2022-04-06 11:11:33,228 - num_train_docs: None
# ...

# %%
#evaluate person only model 
# !python auto_memory_model/main.py -dataset litbank_person_only -mem_type learned -num_cells 20 -top_span_ratio 0.3 -max_span_width 20 -max_epochs 25 -dropout_rate 0.3 -sample_invalid 0.25 -new_ent_wt 2.0 -cross_val_split 3 -max_training_segments 5 -seed 0 -eval True -mention_model ment_litbank_person_only_width_20_mlp_3000_model_large_emb_attn_type_spanbert_enc_overlap_segment_512 -eval_model coref_04657d4d68300a4a7cb80b08a21103ea
# Out:
# ../models/coref_04657d4d68300a4a7cb80b08a21103ea
# ../data/litbank_person_only/overlap/3
# ../models/ment_litbank_person_only_width_20_mlp_3000_model_large_emb_attn_type_spanbert_enc_overlap_segment_512/best_models/model.pth
# 2022-04-03 09:19:05,044 - dataset: litbank_person_only
# 2022-04-03 09:19:05,044 - model_size: large
# 2022-04-03 09:19:05,045 - doc_enc: overlap
# 2022-04-03 09:19:05,045 - max_segment_len: 512
# 2022-04-03 09:19:05,045 - max_span_width: 20
# 2022-04-03 09:19:05,045 - ment_emb: attn
# 2022-04-03 09:19:05,045 - top_span_ratio: 0.3
# 2022-04-03 09:19:05,045 - mem_type: learned
# 2022-04-03 09:19:05,045 - num_cells: 20
# 2022-04-03 09:19:05,045 - mlp_size: 3000
# 2022-04-03 09:19:05,045 - mlp_depth: 1
# 2022-04-03 09:19:05,045 - entity_rep: wt_avg
# 2022-04-03 09:19:05,045 - emb_size: 20
# 2022-04-03 09:19:05,045 - cross_val_split: 3
# 2022-04-03 09:19:05,046 - new_ent_wt: 2.0
# 2022-04-03 09:19:05,046 - num_train_docs: None
# ...

# %%
#TO BEAT: Precision 73.2 Recall 76.8 F-Score: 75.0 All default hyperparams

# %%
# !python auto_memory_model/main.py -dataset litbank_person_only -mem_type learned -num_cells 20 -top_span_ratio 0.25 -max_span_width 20 -max_epochs 15 -dropout_rate 0.3 -sample_invalid 0.25 -new_ent_wt 2.0 -cross_val_split 3 -max_training_segments 5 -seed 0 -mention_model ment_litbank_person_only_width_20_mlp_3000_model_large_emb_attn_type_spanbert_enc_overlap_segment_512 -delete True -trainer james
# Out:
# ../models/../james/models/coref_9771d286e25da3bb826b07b433f5b9f0
# ../data/litbank_person_only/overlap/3
# ../models/ment_litbank_person_only_width_20_mlp_3000_model_large_emb_attn_type_spanbert_enc_overlap_segment_512/best_models/model.pth
# 2022-04-05 21:42:22,769 - dataset: litbank_person_only
# 2022-04-05 21:42:22,769 - model_size: large
# 2022-04-05 21:42:22,769 - doc_enc: overlap
# 2022-04-05 21:42:22,769 - max_segment_len: 512
# 2022-04-05 21:42:22,769 - max_span_width: 20
# 2022-04-05 21:42:22,769 - ment_emb: attn
# 2022-04-05 21:42:22,769 - top_span_ratio: 0.25
# 2022-04-05 21:42:22,770 - mem_type: learned
# 2022-04-05 21:42:22,770 - num_cells: 20
# 2022-04-05 21:42:22,770 - mlp_size: 3000
# 2022-04-05 21:42:22,770 - mlp_depth: 1
# 2022-04-05 21:42:22,770 - entity_rep: wt_avg
# 2022-04-05 21:42:22,770 - emb_size: 20
# 2022-04-05 21:42:22,770 - cross_val_split: 3
# 2022-04-05 21:42:22,770 - new_ent_wt: 2.0
# 2022-04-05 21:42:22,770 - num_train_docs: None
# ...
